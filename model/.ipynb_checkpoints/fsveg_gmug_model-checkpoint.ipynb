# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
from tqdm import tqdm
from itertools import product
from scipy.stats import linregress

import rasterio
from rasterio.windows import Window
from rasterio.transform import Affine
from rasterio.mask import mask

from joblib import Parallel, delayed 

sys.path.append('/global/home/users/erin_carroll/SUFHER')
from utilities import *

# %%
# define filepaths, objects

home = '/global/scratch/users/erin_carroll/'
tif_folder = home+'/data/tifs/GMUG_/'
years = range(2018,2025)
months = ['jul','aug','sep']
indices = ['NDMI', 'NDVI']

# %%
########################
## TREND POLYGONS
########################

# %%
# load spatial data

gmug = gpd.read_file(home+'data/spatial_data/gmug/').to_crs(32613)
# fsveg = gpd.read_file(home+'SUFHER/shp/FSVegSpatial2Feb2021/FSVegSpatial2Feb2021.shp').to_crs(32613)
fsveg = gpd.read_file(home+'SUFHER/shp/FSVegSpatial2Feb2021.gpkg').to_crs(32613)
print(fsveg.crs, gmug.crs)
# Out:
# epsg:32613 epsg:32613

# %%
# filter fsveg to intersects GMUG
print(len(fsveg))
fsveg = gpd.sjoin(fsveg, gmug, op='intersects')
len(fsveg)
# Out:
# 66010
# 64111

# %%
size_bytes = fsveg.memory_usage(deep=True).sum()
print(f"Approximate memory usage: {size_bytes / 1e6:.2f} MB")
# Out:
# Approximate memory usage: 361.42 MB

# %%
# filter fsveg to useful columns
fsveg = fsveg[['ACRES', 'COVER_TYPE', 'LOCAL_TYPE', 'STAND_ID', 'ASPECT_CLA', 'ELEVATION_', 'SLOPE_PERC', 'geometry']].reset_index()

# %%
size_bytes = fsveg.memory_usage(deep=True).sum()
print(f"Approximate memory usage: {size_bytes / 1e6:.2f} MB")
# Out:
# Approximate memory usage: 18.74 MB

# %%
# visualize
fig, ax = plt.subplots()
fsveg.plot(ax=ax, column='LOCAL_TYPE')
gmug.boundary.plot(ax=ax, color='black')

ax.set_xlim([200000, 240000])
ax.set_ylim([4200000, 4250000])

plt.show()

# %%
# STAND_ID is almost but not fully unique? Assign a unique id
print(len(fsveg) - len(fsveg.STAND_ID.unique()))
fsveg['unique_id'] = range(0, len(fsveg))
# Out:
# 5805

# %%
fps = sorted(glob(tif_folder+f'/*/*/*.tif'))
args = list(product(fps, [fsveg]))

dfs = Parallel(n_jobs=20)(
    delayed(raster_data_to_polygon)(raster_fp, shp) for raster_fp, shp in args
)
# ~ 6 mins

# %%
fsveg_ = pd.concat(dfs, ignore_index=True)
fsveg_['name'] = fsveg_['idx']+'_'+fsveg_['year']+'_'+fsveg_['month']+'_mean'
fsveg_
# Out:
#          index   ACRES COVER_TYPE LOCAL_TYPE         STAND_ID ASPECT_CLA  \
# 0            0   32.25        TSF        TSF  020508550202027         NO
# 1            1   74.97        TAA     TAA-SW  020507BE0102064         SW
# 2            2   19.37        TAA     TAA-SW  022402130702113         SW
# 3            3   29.44        TAA     TAA-SW  020508530500592         SO
# 4            4   39.30        TSF        TSF  020507990900112         NW
# ...        ...     ...        ...        ...              ...        ...
# 3077323  66004  292.16        NBA        NRS  020406790107018         NW
# 3077324  66005  292.16        NBA        NRS  020406790107018         NW
# 3077325  66006  292.16        NBA        NRS  020406790107018         NW
# 3077326  66008  292.16        NBA        NRS  020406790107018         NW
# 3077327  66009  292.16        NBA        NRS  020406790107018         NW
#
#          ELEVATION_  SLOPE_PERC  \
# 0              9381          17
# 1             10471          30
# 2              9661          26
# 3              9874          36
# 4             10134          48
# ...             ...         ...
# 3077323       10440          63
# 3077324       10440          63
# 3077325       10440          63
# 3077326       10440          63
# 3077327       10440          63
#
#                                                   geometry  unique_id  \
# 0        MULTIPOLYGON (((274391.174 4332930.027, 274355...          0
# 1        MULTIPOLYGON (((333586.027 4236428.430, 333488...          1
# 2        MULTIPOLYGON (((247168.243 4323317.932, 247148...          2
# 3        MULTIPOLYGON (((291081.775 4270439.309, 291040...          3
# 4        MULTIPOLYGON (((329293.499 4314347.808, 329269...          4
# ...                                                    ...        ...
# 3077323  MULTIPOLYGON (((234101.641 4327203.226, 234089...      64106
# 3077324  MULTIPOLYGON (((323804.162 4311369.581, 323802...      64107
# 3077325  MULTIPOLYGON (((385935.283 4249324.664, 385929...      64108
# 3077326  MULTIPOLYGON (((331383.959 4238061.126, 331368...      64109
# 3077327  MULTIPOLYGON (((323037.048 4308527.115, 323023...      64110
#
#               min      mean       max       std  year month   idx  \
# 0        0.025536  0.131797  0.271962  0.044391  2017   jul  NDMI
# 1        -0.01784  0.228635  0.346643  0.067949  2017   jul  NDMI
# 2        0.038693  0.202653   0.34815  0.048485  2017   jul  NDMI
# 3        0.110472  0.282901  0.385819  0.039428  2017   jul  NDMI
# 4       -0.199894  0.106864  0.254933  0.063328  2017   jul  NDMI
# ...           ...       ...       ...       ...   ...   ...   ...
# 3077323  0.127786  0.359783  0.578457   0.05302  2024   sep  NDVI
# 3077324  0.212739  0.344658  0.533737  0.054093  2024   sep  NDVI
# 3077325   0.19223  0.395698   0.58214   0.08977  2024   sep  NDVI
# 3077326   0.07939   0.13858  0.458154  0.066511  2024   sep  NDVI
# 3077327  0.067661  0.391688  0.582166  0.095749  2024   sep  NDVI
#
#                        name
# 0        NDMI_2017_jul_mean
# 1        NDMI_2017_jul_mean
# 2        NDMI_2017_jul_mean
# 3        NDMI_2017_jul_mean
# 4        NDMI_2017_jul_mean
# ...                     ...
# 3077323  NDVI_2024_sep_mean
# 3077324  NDVI_2024_sep_mean
# 3077325  NDVI_2024_sep_mean
# 3077326  NDVI_2024_sep_mean
# 3077327  NDVI_2024_sep_mean
#
# [3077328 rows x 18 columns]

# %%
##########################
## Run models on polygons
##########################

# %%
# create decimal_year time variable
month_map = {'jul': 7, 'aug': 8, 'sep': 9}
fsveg_['month_num'] = fsveg_['month'].map(month_map)
fsveg_['year'] = fsveg_['year'].astype(int)
fsveg_['mean'] = fsveg_['mean'].astype(float)


fsveg_['decimal_time'] = fsveg_['year'] + (fsveg_['month_num'] - 1) / 12

# %%
# remove 2017
fsveg_ = fsveg_[fsveg_['year']!=2017]
len(fsveg_)
# Out:
# 2692662

# %%
# define a function to fit a linear model and return slope and p-value
def fit_slope(group):
    if len(group) < 2 or group['mean'].isnull().all():
        return pd.Series({'slope': float('nan'), 'p_value': float('nan')})
    result = linregress(group['decimal_time'], group['mean'])
    return pd.Series({'slope': result.slope, 'p_value': result.pvalue})

# %%
# deploy per unique polygon
fsveg_model = fsveg_.groupby(['unique_id', 'ACRES', 'LOCAL_TYPE', 'STAND_ID', 'idx']).apply(fit_slope).reset_index()

# %%
# convert back to wide
fsveg_model_wide = fsveg_model.pivot_table(index=['unique_id', 'ACRES', 'LOCAL_TYPE', 'STAND_ID'],
                   columns='idx',
                   values=['slope', 'p_value']).reset_index()
fsveg_model_wide.columns = ['_'.join([str(i) for i in col if i]) if isinstance(col, tuple) else col
                            for col in fsveg_model_wide.columns]

# %%
# reattch to geometry

# %%
id_cols = ['unique_id']
geom = fsveg_.drop_duplicates(subset=id_cols)[id_cols+['ASPECT_CLA', 'ELEVATION_', 'SLOPE_PERC', 'geometry']]

# %%
fsveg_model_geom = fsveg_model_wide.merge(geom[['unique_id', 'ASPECT_CLA', 'ELEVATION_', 'SLOPE_PERC', 'geometry']], on='unique_id', how='left')
fsveg_model_geom = gpd.GeoDataFrame(fsveg_model_geom, geometry='geometry', crs=geom.crs)

# %%
# export

# %%
fp_out = home+'SUFHER/shp/fsveg_gmug.gpkg'
fsveg_model_geom.to_file(fp_out, driver="GPKG")

# %%
fsveg_model_geom = fsveg_model_geom.rename(columns={
    'p_value_NDMI': 'p_NDMI',
    'p_value_NDVI': 'p_NDVI'
})

# %%
fp_out = home+'SUFHER/shp/fsveg_gmug/fsveg_gmug.shp'
fsveg_model_geom.to_file(fp_out)

# %%
# to csv for Ben
fp_out = home+'SUFHER/fsveg_gmug_topo.csv'
df = fsveg_model_geom.drop(columns='geometry')
df.to_csv(fp_out, index=False)
